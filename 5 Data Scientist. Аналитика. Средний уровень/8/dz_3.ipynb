# %%
import pandas as pd

# %%
df = pd.read_excel('data/Dataset-2.xlsx', sheet_name='Лист2')
df
# Out:
#        Date        Выручка  % доступности           MAU    Новые  \
# 0   02.сент  600000.000000             91  6.209971e+06  1271736
# 1   03.сент  539800.000000             98  6.138791e+06  1447192
# 2   05.сент  809765.000000             92  6.392179e+06  1195080
# 3   06.сент  978651.000000            100  7.697321e+06  1387697
# 4   07.сент  769542.000000             97  6.698070e+06  1752918
# ..      ...            ...            ...           ...      ...
# 82  25.нояб  342363.574767             92  4.975691e+06  1928454
# 83  26.нояб  407430.019645             91  4.452613e+06  1071735
# 84  27.нояб  154015.002726             94  4.474282e+06  1989154
# 85  29.нояб  221581.639882             94  3.860038e+06  1539114
# 86  30.нояб  546252.628780             98  5.050528e+06  1703268
#
#      Вернувшиеся  Количество операций  Ошибки  Средний чек  % доступности.1  \
# 0   4.938235e+06          1218.323587    3715   492.480000         0.703224
# ...

# %%
corr_dostupnosti = df['% доступности'].corr(df['Выручка'])
corr_mau = df['MAU'].corr(df['Выручка'])
corr_new = df['Новые'].corr(df['Выручка'])
corr_returned = df['Вернувшиеся'].corr(df['Выручка'])
corr_operation_count = df['Количество операций'].corr(df['Выручка'])
corr_errors = df['Ошибки'].corr(df['Выручка'])
corr_mid_check = df['Средний чек'].corr(df['Выручка'])
print(corr_dostupnosti)
print(corr_mau)
print(corr_new)
print(corr_returned)
print(corr_operation_count)
print(corr_errors)
print(corr_mid_check)
# Out:
# 0.7032239575708845
# 0.8840775937186734
# -0.06913465128212332
# 0.854884004355467
# 0.34276783902252717
# -0.3481097246968701
# 0.6564130144758317
