# %%
from sympy import *
import numpy as np
from sympy.plotting import plot3d
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x, y = symbols('x, y')

# %%
f = sin(sqrt(x**2 + y**2))

# %%
plot3d(f)

# %%
f = E**(-0.9*x**2-0.45*(x-y)**2)
f
# Out:
#         2               2
#  - 0.9*x  - 0.45*(x - y)
# e

# %%
plot3d(f, (x, -3, 3), (y, -3, 3))

# %%
f = x*cos(y)
plot3d(f)
