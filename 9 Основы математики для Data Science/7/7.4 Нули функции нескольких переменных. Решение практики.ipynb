# %%
from sympy import *
from sympy.plotting import plot3d
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x, y = symbols('x, y')

# %% [markdown]
# ## 1.

# %%
f = 2 * x + 5 * y + 1
f
# Out:
# 2*x + 5*y + 1

# %%
plot3d(f)

# %%
solve(f)
# Out:
#        5*y   1
# [{x: - --- - -}]
#         2    2

# %%
f = - 5 * y / 2 - 1 / 2
f
# Out:
#   5*y
# - --- - 0.5
#    2

# %%
plot(f)

# %% [markdown]
# ## 2.

# %%
f = x**2 + y**2 - 1
f
# Out:
#  2    2
# x  + y  - 1

# %%
plot3d(f)

# %%
solve(f)
# Out:
#          ________          ________
#         /      2          /      2
# [{x: -\/  1 - y  }, {x: \/  1 - y  }]

# %%
f = - sqrt(1 - y**2)
f
# Out:
#     ________
#    /      2
# -\/  1 - y

# %%
plot(f, (y, -1, 1))

# %%
f = sqrt(1 - y**2)
f
# Out:
#    ________
#   /      2
# \/  1 - y

# %%
plot(f, (y, -1, 1))

# %% [markdown]
# ## 3.

# %%
f = x * cos(y)
f
# Out:
# x*cos(y)

# %%
plot3d(f)

# %%
solve(f)
# Out:
#              pi       3*pi
# [{x: 0}, {y: --}, {y: ----}]
#              2         2
