# %%
from sympy import *

# %%
A11 = Matrix.det(Matrix([[1, 1], [-6, 2]]))
A11
# Out:
# 8

# %%
A12 = -1*Matrix.det(Matrix([[0, 1], [-4, 2]]))
A13 = Matrix.det(Matrix([[0, 1], [-4, -6]]))
A21 = -1*Matrix.det(Matrix([[3, -1], [-6, 2]]))
A22 = Matrix.det(Matrix([[2, -1], [-4, 2]]))
A23 = -1*Matrix.det(Matrix([[2, 3], [-4, -6]]))
A31 = Matrix.det(Matrix([[3, -1], [0, 1]]))
A32 = -1*Matrix.det(Matrix([[2, -1], [0, 1]]))
A33 = Matrix.det(Matrix([[2, 3], [0, 1]]))

# %%
Apl = Matrix([[A11, A12, A13], [A21, A22, A23], [A31, A32, A33]])
Apl
# Out:
# Matrix([
# [8, -4, 4],
# [0,  0, 0],
# [3, -2, 2]])

# %%
B11 = Matrix.det(Matrix([[-1, 1], [3, -1]]))
B12 = -1*Matrix.det(Matrix([[2, 1], [1, -1]]))
B13 = Matrix.det(Matrix([[2, -1], [1, 3]]))
B21 = -1*Matrix.det(Matrix([[0, 2], [3, -1]]))
B22 = Matrix.det(Matrix([[1, 2], [1, -1]]))
B23 = -1*Matrix.det(Matrix([[1, 0], [1, 3]]))
B31 = Matrix.det(Matrix([[0, 2], [-1, 1]]))
B32 = -1*Matrix.det(Matrix([[1, 2], [2, 1]]))
B33 = Matrix.det(Matrix([[1, 0], [2, -1]]))

# %%
Bpl = Matrix([[B11, B12, B13], [B21, B22, B23], [B31, B32, B33]])
Bpl
# Out:
# Matrix([
# [-2,  3,  7],
# [ 6, -3, -3],
# [ 2,  3, -1]])

# %%
C = Matrix([[1, 3, 5], [0, 1, 2], [0, 0, 1]])
D = Matrix.det(C)
D
# Out:
# 1
