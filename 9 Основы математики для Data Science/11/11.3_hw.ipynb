# %%
from sympy import *

# %%
A = Matrix([[3, 4], [10, 2]])
A
# Out:
# Matrix([
# [ 3, 4],
# [10, 2]])

# %%
B = Matrix([[4, 8], [2, 4]])
A*B
# Out:
# Matrix([
# [20, 40],
# [44, 88]])

# %%
A1 = Matrix([[3, -4], [10, -2]])
B*A1
# Out:
# Matrix([
# [92, -32],
# [46, -16]])

# %%
C = Matrix([[3, -4, 1], [10, -2, 2]])
D = Matrix([[7, 13], [-4, 5], [5, 6]])
C*D
# Out:
# Matrix([
# [42,  25],
# [88, 132]])

# %%
E = Matrix([[10, 4, 5, 7], [5, 14, 6, 2]])
D1 = Matrix([[7, 13], [-4, 5], [9, 3]])
D1*E
# Out:
# Matrix([
# [135, 210, 113,  75],
# [-15,  54,  10, -18],
# [105,  78,  63,  69]])

# %%
Det = Matrix.det(A)
Det
# Out:
# -34

# %%
Ao = Matrix.inv(A)
Ao
# Out:
# Matrix([
# [-1/17,  2/17],
# [ 5/17, -3/34]])

# %%
Det = Matrix.det(B)
Det
# Out:
# 0

# %%
D = Matrix([[7, 13], [-4, 5]])
Det = Matrix.det(D)
Det
# Out:
# 87

# %%
Do = Matrix.inv(D)
Do
# Out:
# Matrix([
# [5/87, -13/87],
# [4/87,   7/87]])

# %%
E = Matrix([[10, 4], [5, 14]])
Det = Matrix.det(E)
Det
# Out:
# 120

# %%
Eo = Matrix.inv(E)
Eo
# Out:
# Matrix([
# [ 7/60, -1/30],
# [-1/24,  1/12]])
