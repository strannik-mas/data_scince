# %%
from sympy import *

# %%
Ao = 1/(-2*7 - 3*4) * Matrix([[7, -4], [-3, 2]])
Ao
# Out:
# Matrix([
# [-0.269230769230769,   0.153846153846154],
# [ 0.115384615384615, -0.0769230769230769]])

# %%
Ao = 1/(8*3 - 5*1) * Matrix([[3, -1], [-5, 8]])
Ao
# Out:
# Matrix([
# [ 0.157894736842105, -0.0526315789473684],
# [-0.263157894736842,   0.421052631578947]])

# %% [markdown]
# 2 уравнения

# %%
Ao = 1/(2*(-3)- 5*7) * Matrix([[-3, -5], [-7, 2]])
otv = Ao * Matrix([11, -23])
otv
# Out:
# Matrix([
# [-2.0],
# [ 3.0]])

# %%
x, y = symbols('x, y')
a, b = symbols('a, b')

# %%
eq1 = 2*x + 5*y - 11
eq2 = 7*x - 3*y + 23
linsolve([eq1, eq2], [x, y])
# Out:
# {(-2, 3)}

# %%
Ao = 1/(5*(-3)- 1*3) * Matrix([[5, -1], [-3, -3]])
otv = Ao * Matrix([-2, 8])
otv
# Out:
# Matrix([
# [1.0],
# [1.0]])

# %%
eq1 = -3*x + y +2
eq2 = 3*x + 5*y - 8
linsolve([eq1, eq2], [x, y])
# Out:
# {(1, 1)}

# %%
Ao = 1/(2*(-1)- 3*3) * Matrix([[-1, -3], [-3, 2]])
otv = Ao * Matrix([12, 7])
otv
# Out:
# Matrix([
# [3.0],
# [2.0]])

# %%
eq1 = 2*x + 3*y - 12
eq2 = 3*x - y - 7
linsolve([eq1, eq2], [x, y])
# Out:
# {(3, 2)}
