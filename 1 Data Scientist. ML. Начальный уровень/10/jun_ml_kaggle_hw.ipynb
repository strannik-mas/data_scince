# %% [markdown]
# # Kaggle
#
# В этом домашнем задании вам нужно будет построить модель для данных соревнования [Titanic на Kaggle](https://www.kaggle.com/c/titanic/overview), сформировать файл с предсказаниями для тестовых данных и отправить его на проверку.
#
# В практике из урока вашим заданием было разобрать одно из самых популярных ядер для соревнования Titanic и преобразовать его таким образом, чтобы остались только преобразование данных и графики.
#
# Соответственно, сейчас ваше ядро должно выглядеть таким образом:

# %%
import pandas as pd
import re
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Load in the train and test datasets
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# Store our passenger ID for easy access
PassengerId = test['PassengerId']

train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
full_data = [train, test]

# Gives the length of the name
train['Name_length'] = train['Name'].apply(len)
test['Name_length'] = test['Name'].apply(len)
# Feature that tells whether a passenger had a cabin on the Titanic
train['Has_Cabin'] = train["Cabin"].apply(lambda x: 0 if type(x) == float else 1)
test['Has_Cabin'] = test["Cabin"].apply(lambda x: 0 if type(x) == float else 1)

# Create new feature FamilySize as a combination of SibSp and Parch
for dataset in full_data:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
# Create new feature IsAlone from FamilySize
for dataset in full_data:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1
# Remove all NULLS in the Embarked column
for dataset in full_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')
# Remove all NULLS in the Fare column and create a new feature CategoricalFare
for dataset in full_data:
    dataset['Fare'] = dataset['Fare'].fillna(train['Fare'].median())
train['CategoricalFare'] = pd.qcut(train['Fare'], 4)
# Create a New feature CategoricalAge
for dataset in full_data:
    age_avg = dataset['Age'].mean()
    age_std = dataset['Age'].std()
    age_null_count = dataset['Age'].isnull().sum()
    age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)
    dataset['Age'][np.isnan(dataset['Age'])] = age_null_random_list
    dataset['Age'] = dataset['Age'].astype(int)
train['CategoricalAge'] = pd.cut(train['Age'], 5)
# Define function to extract titles from passenger names
def get_title(name):
    title_search = re.search(' ([A-Za-z]+)\.', name)
    # If the title exists, extract and return it.
    if title_search:
        return title_search.group(1)
    return ""
# Create a new feature Title, containing the titles of passenger names
for dataset in full_data:
    dataset['Title'] = dataset['Name'].apply(get_title)
# Group all non-common titles into one single grouping "Rare"
for dataset in full_data:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

for dataset in full_data:
    # Mapping Sex
    dataset['Sex'] = dataset['Sex'].map( {'female': 0, 'male': 1} ).astype(int)

    # Mapping titles
    title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

    # Mapping Embarked
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

    # Mapping Fare
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

    # Mapping Age
    dataset.loc[ dataset['Age'] <= 16, 'Age'] 					       = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age'] = 4

# %%
# Feature selection
drop_elements = ['PassengerId', 'Name', 'Ticket', 'Cabin', 'SibSp']
train = train.drop(drop_elements, axis = 1)
train = train.drop(['CategoricalAge', 'CategoricalFare'], axis = 1)
test  = test.drop(drop_elements, axis = 1)

# %%
train.head(3)
# Out:
#    Survived  Pclass  Sex  Age  Parch  Fare  Embarked  Name_length  Has_Cabin  \
# 0         0       3    1    1      0     0         0           23          0
# 1         1       1    0    2      0     3         1           51          1
# 2         1       3    0    1      0     1         0           22          0
#
#    FamilySize  IsAlone  Title
# 0           2        0      1
# 1           2        0      3
# 2           1        1      2

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(train.astype(float).corr(),linewidths=0.1,vmax=1.0,
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <Axes: title={'center': 'Pearson Correlation of Features'}>

# %%
g = sns.pairplot(train[[u'Survived', u'Pclass', u'Sex', u'Age', u'Parch', u'Fare',
                        u'Embarked', u'FamilySize', u'Title']],
                 hue='Survived', palette = 'seismic', size=1.2, plot_kws=dict(s=10))
g.set(xticklabels=[])

# %% [markdown]
# Итак, у нас получились два датасета с новыми признаками. Теперь приступим к построению модели.
#
# ### Построение модели
#
# ### 1.
#
# Воспользуйтесь вашим алгоритмом стекинга из предыдущего домашнего задания. В качестве базовых алгоритмов используйте RandomForestClassifier, SVC, GradientBoostingClassifier и LogisticRegression; в качестве мета-алгоритма - XGBoost.
#
# Разделите данные train на тренировочную и валидационную выборки с random_state=17 и параметром разбиения test_size=.3 (в качестве целевой переменной возьмите столбец Survived, а в качестве признаков - все остальные столбцы).
#
# Ниже приведены параметры для каждого из базовых алгоритмов, которые необходимо настроить на 5-кратной кросс-валидации с помощью GridSearchCV:

# %%
from sklearn.model_selection import (GridSearchCV,
                                     train_test_split,
                                     cross_val_predict,
                                     StratifiedKFold)

from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

from xgboost import XGBClassifier

# параметры базовых алгоритмов
gbc_params = {'learning_rate': np.arange(0.1, 0.6, 0.1)} # GradientBoostingClassifier

rfc_params = {'n_estimators': range(10, 100, 10), # RandomForestClassifier
              'min_samples_leaf': range(1, 5)}

svc_params = {'kernel': ['linear', 'rbf'], # SVC
              'C': np.arange(0.1, 1, 0.2)}

lr_params = {'C': np.arange(0.5, 1, 0.1)}

skf = StratifiedKFold(n_splits=5, shuffle=True,random_state=17)

X = train.drop('Survived', axis=1)
y = train['Survived']

X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, test_size=0.3, random_state=17, stratify=y
)

# %% [markdown]
# ### 2.
# 1. Определите объект GridSearchCV для всех приведенных параметров каждого алгоритма (в гиперпараметрах алгоритма при его определении, если возможно, укажите random_state=17). Параметр cv устанавливайте равным skf.
#
# 2. Обучите каждый из объектов из 1-го пункта на получившейся при разбиении тренировочной выборке. Выведите лучшее сочетание параметров для каждого из алгоритмов.
#
# 3. Для каждого обученного алгоритма получите предсказания на валидационных данных и выведите метрику качества, которая соответствует метрике оценки соревнования.

# %%
# ваш код
from sklearn.metrics import accuracy_score
rfc = RandomForestClassifier(random_state=17)
rf_grid = GridSearchCV(rfc, rfc_params, cv=skf, scoring='accuracy', n_jobs=-1)

svc = SVC(probability=True, random_state=17)  # random_state работает для некоторых ядер (poly, sigmoid)
svc_grid = GridSearchCV(svc, svc_params, cv=skf, scoring='accuracy', n_jobs=-1)

gb = GradientBoostingClassifier(random_state=17)
gb_grid = GridSearchCV(gb, gbc_params, cv=skf, scoring='accuracy', n_jobs=-1)

lr = LogisticRegression(random_state=17, max_iter=1000)
lr_grid = GridSearchCV(lr, lr_params, cv=skf, scoring='accuracy', n_jobs=-1)

meta_features_val = pd.DataFrame()

# Обучаем и выводим лучшие параметры для каждого алгоритма
for name, grid in [
    ("Random Forest", rf_grid),
    ("SVC", svc_grid),
    ("Gradient Boosting", gb_grid),
    ("Logistic Regression", lr_grid)
]:
    grid.fit(X_train, y_train)
    best_model = grid.best_estimator_
    # Для вероятностей
    if hasattr(best_model, "predict_proba"):
        preds = best_model.predict_proba(X_valid)[:, 1]
    else:
        # например, если SVC без probability=True
        preds = best_model.decision_function(X_valid)
    
    meta_features_val[name] = preds
    y_pred = best_model.predict(X_valid)
    acc = accuracy_score(y_valid, y_pred)
    
    print(f"{name}:")
    print("Best parameters:", grid.best_params_)
    print("Best CV score:", grid.best_score_)
    print(f"Validation Accuracy: {acc:.4f}")
    print("-" * 50)
# Out:
# Random Forest:
# Best parameters: {'min_samples_leaf': 4, 'n_estimators': 10}
# Best CV score: 0.8251225806451613
# Validation Accuracy: 0.8134
# --------------------------------------------------
# SVC:
# Best parameters: {'C': np.float64(0.1), 'kernel': 'linear'}
# Best CV score: 0.8138322580645161
# Validation Accuracy: 0.8097
# --------------------------------------------------
# Gradient Boosting:
# Best parameters: {'learning_rate': np.float64(0.2)}
# Best CV score: 0.8218838709677418
# Validation Accuracy: 0.8097
# --------------------------------------------------
# Logistic Regression:
# Best parameters: {'C': np.float64(0.7)}
# Best CV score: 0.8106838709677419
# Validation Accuracy: 0.8134
# --------------------------------------------------

# %% [markdown]
# ### 3.
# С помощью GridSearchCV и указанных ниже параметров настройте мета-алгоритм на мета-признаках (используйте 5-кратную валидацию и random_state=17 при определении алгоритма). Матрицу метапризнаков получите из предсказаний, полученных в предыдущем пункте на валидационных данных базовыми алгоритмами. Выведите лучшие параметры.

# %%
xgb_params = {'n_estimators': range(10, 100, 5),
              'eta': np.arange(0.1, 1., .1),
              'min_child_weight': range(1, 10, 1),
              'subsample': np.arange(0.1, 1., 0.2)}

# %%
# ваш код
# Определяем мета-алгоритм
meta_model = XGBClassifier(
    random_state=17,
    use_label_encoder=False,
    eval_metric='logloss'  # чтобы XGBoost не ругался
)

# Настройка через GridSearchCV
meta_grid = GridSearchCV(
    estimator=meta_model,
    param_grid=xgb_params,
    cv=skf,  # 5-кратная стратифицированная кросс-валидация
    scoring='accuracy',
    n_jobs=-1
)

# Обучаем на метапризнаках
meta_grid.fit(meta_features_val, y_valid)

# Лучшие параметры
print("Лучшие параметры для мета-алгоритма XGBoost:")
print(meta_grid.best_params_)
print(f"Лучшая метрика: {meta_grid.best_score_:.4f}")
# Out:
# Лучшие параметры для мета-алгоритма XGBoost:
# {'eta': np.float64(0.4), 'min_child_weight': 1, 'n_estimators': 40, 'subsample': np.float64(0.1)}
# Лучшая метрика: 0.8390

# %% [markdown]
# ### 4.
# На основе алгоритма из предыдущего домашнего задания постройте стекинг (используйте 5-кратную кросс-валидацию) для всех моделей с наилучшими подобранными параметрами. В качестве тренировочных данных используйте весь датасет train.csv, а в качестве тестовых - весь датасет test.csv. Сделайте прогноз мета-алгоритма для test.csv.

# %%
# ваш код
X_full = train.drop('Survived', axis=1)
y_full = train['Survived']
X_test = test.copy()

# ------------------------------------------------------
# 2) Лучшие базовые модели из GridSearchCV
#    (предполагается, что rf_grid, svc_grid, gb_grid, lr_grid уже fit)
# ------------------------------------------------------
rf_best  = rf_grid.best_estimator_
svc_best = svc_grid.best_estimator_
gb_best  = gb_grid.best_estimator_
lr_best  = lr_grid.best_estimator_

base_models = [
    ('RF',  rf_best),
    ('SVC', svc_best),
    ('GB',  gb_best),
    ('LR',  lr_best),
]

# 5-кратная стратифицированная CV
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=17)

# ------------------------------------------------------
# 3) OOF-метапризнаки для train (строки = объекты, столбцы = модели)
# ------------------------------------------------------
meta_train_cols = [name for name, _ in base_models]
meta_train = []

for name, model in base_models:
    if hasattr(model, "predict_proba"):
        # вероятность класса 1
        oof = cross_val_predict(model, X_full, y_full, cv=skf, method='predict_proba')[:, 1]
    else:
        # fallback для моделей без predict_proba (например, SVC без probability=True)
        oof = cross_val_predict(model, X_full, y_full, cv=skf, method='decision_function')
    meta_train.append(oof)

meta_train_df = pd.DataFrame(np.column_stack(meta_train), columns=meta_train_cols)

# ------------------------------------------------------
# 4) Метапризнаки для test:
#    дообучаем каждую базовую модель на ВСЁМ train и предсказываем на всём test
# ------------------------------------------------------
meta_test = []
for name, model in base_models:
    model.fit(X_full, y_full)
    if hasattr(model, "predict_proba"):
        preds = model.predict_proba(X_test)[:, 1]
    else:
        preds = model.decision_function(X_test)
    meta_test.append(preds)

meta_test_df = pd.DataFrame(np.column_stack(meta_test), columns=meta_train_cols)

# ------------------------------------------------------
# 5) Мета-алгоритм XGBoost
#    Если раньше ты уже настраивал meta_grid = GridSearchCV(...),
#    возьми лучшие параметры; иначе можно задать свои.
# ------------------------------------------------------
# Если есть meta_grid из предыдущего шага:
# best_xgb_params = meta_grid.best_params_

# Если нет — можно задать разумные стартовые параметры:
best_xgb_params = {
    'n_estimators': 200,
    'eta': 0.1,
    'min_child_weight': 1,
    'subsample': 0.8,
}

meta_clf = XGBClassifier(
    random_state=17,
    use_label_encoder=False,
    eval_metric='logloss',
    **best_xgb_params
)

# Обучаем мета-модель на OOF-метапризнаках
meta_clf.fit(meta_train_df, y_full)

# Прогноз для test.csv
test_pred = meta_clf.predict(meta_test_df).astype(int)

# %% [markdown]
# ### 5.
# С помощью нижеприведенной функции сформируйте файл посылки для соревнования и отправьте на Kaggle.

# %%
def write_to_submission_file(predictions, PassengerID, out_file='Submission.csv', columns=['PassengerID', 'Survived']):
    predicted_df = pd.DataFrame(np.array([PassengerId, test_pred]).T, columns=columns)
    predicted_df.to_csv(out_file, index=False)

# %%
# ваш код
# Запишем файл для Kaggle
write_to_submission_file(test_pred, PassengerId, out_file='stacking_submission.csv')

print("Файл 'stacking_submission.csv' готов для отправки на Kaggle!")
# Out:
# Файл 'stacking_submission.csv' готов для отправки на Kaggle!

# %% [markdown]
# ### 6.
# Каков результат score, полученного на соревновании?

# %% [markdown]
# Ваш ответ:
